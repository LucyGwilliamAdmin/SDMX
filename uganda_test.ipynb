# %% [markdown]
# ## Import libraries

# %%
import lxml.etree as ET
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import files

# %%
xml_file = ET.parse("UG_DATA.xml")
xml = xml_file.getroot()

# %%
mapping=pd.read_csv("codelists.csv")
mapping
# Out:
#           Codelist                     Code  \
# 0             FREQ                        A
# 1             FREQ                        S
# 2             FREQ                        Q
# 3             FREQ                        M
# 4             FREQ                        W
# 5             FREQ                        D
# 6             FREQ                        H
# 7             FREQ                        B
# 8             FREQ                        N
# 9       OBS_STATUS                        A
# 10      OBS_STATUS                        B
# 11      OBS_STATUS                        D
# 12      OBS_STATUS                        E
# 13      OBS_STATUS                        F
# 14      OBS_STATUS                        G
# 15      OBS_STATUS                        H
# 16      OBS_STATUS                        I
# 17      OBS_STATUS                        J
# 18      OBS_STATUS                        K
# 19      OBS_STATUS                        L
# 20      OBS_STATUS                        M
# 21      OBS_STATUS                        N
# 22      OBS_STATUS                        O
# 23      OBS_STATUS                        P
# 24      OBS_STATUS                        Q
# 25      OBS_STATUS                        S
# 26      OBS_STATUS                        U
# 27      OBS_STATUS                        V
# 28      OBS_STATUS                        W
# 29       UNIT_MULT                        0
# ...            ...                      ...
# 1239  UNIT_MEASURE              LCU_PPP_USD
# 1240  UNIT_MEASURE   MJ_PER_GDP_CON_PPP_USD
# 1241  UNIT_MEASURE                        T
# 1242  UNIT_MEASURE                   GPERM3
# 1243  UNIT_MEASURE                      NaN
# 1244  UNIT_MEASURE                   NUMBER
# 1245  UNIT_MEASURE              USD_GDP_PPP
# 1246  UNIT_MEASURE     PER_1000_LIVE_BIRTHS
# 1247  UNIT_MEASURE             PER_1000_POP
# 1248  UNIT_MEASURE             PER_1000_USD
# 1249  UNIT_MEASURE  PER_1000_UNINFECTED_POP
# 1250  UNIT_MEASURE      PER_100_LIVE_BIRTHS
# 1251  UNIT_MEASURE              PER_100_POP
# 1252  UNIT_MEASURE           PER_100000_EMP
# 1253  UNIT_MEASURE           PER_100000_FTE
# 1254  UNIT_MEASURE   PER_100000_LIVE_BIRTHS
# 1255  UNIT_MEASURE     PER_100000_PRSN_INSR
# 1256  UNIT_MEASURE           PER_100000_POP
# 1257  UNIT_MEASURE      PER_100000_WKRS_EMP
# 1258  UNIT_MEASURE     PER_100000_WKRS_EXPD
# 1259  UNIT_MEASURE          PER_1000000_POP
# 1260  UNIT_MEASURE                  PERCENT
# 1261  UNIT_MEASURE                     PROB
# 1262  UNIT_MEASURE                    RATIO
# 1263  UNIT_MEASURE                     T_KM
# 1264  UNIT_MEASURE                 T_PER_HA
# 1265  UNIT_MEASURE                      USD
# 1266  URBANISATION                       _T
# 1267  URBANISATION                        U
# 1268  URBANISATION                        R
#
#                                                   Name
# 0                                               Annual
# 1                                Half-yearly, semester
# 2                                            Quarterly
# 3                                              Monthly
# 4                                               Weekly
# 5                                                Daily
# 6                                               Hourly
# 7                                 Daily – businessweek
# 8                                             Minutely
# 9                                         Normal value
# 10                                   Time series break
# 11                                  Definition differs
# 12                                     Estimated value
# 13                                      Forecast value
# 14                                  Experimental value
# 15                   Missing value; holiday or weekend
# 16                     Imputed value (CCSA definition)
# 17                                          Derogation
# 18                   Data included in another category
# 19    Missing value; data exist but were not collected
# 20                    Missing value; data cannot exist
# 21                                     Not significant
# 22                                       Missing value
# 23                                   Provisional value
# 24                           Missing value; suppressed
# 25                     Strike and other special events
# 26                                     Low reliability
# 27                                   Unvalidated value
# 28                 Includes data from another category
# 29                                               Units
# ...                                                ...
# 1239                      Local currency per USD (PPP)
# 1240               Megajoules per USD constant PPP GDP
# 1241                                       Metric Tons
# 1242                        Micrograms per cubic meter
# 1243                                    Not applicable
# 1244                                            Number
# 1245                               Per 1 USD GDP (PPP)
# 1246                             Per 1,000 live births
# 1247                              Per 1,000 population
# 1248                                     Per 1,000 USD
# 1249                   Per 1,000 uninfected population
# 1250                               Per 100 live births
# 1251                                Per 100 population
# 1252                             Per 100,000 employees
# 1253                 Per 100,000 full-time equivalents
# 1254                           Per 100,000 live births
# 1255                       Per 100,000 persons insured
# 1256                            Per 100,000 population
# 1257                      Per 100,000 workers employed
# 1258               Per 100,000 workers exposed to risk
# 1259                            Per million population
# 1260                                           Percent
# 1261                                       Probability
# 1262                                             Ratio
# 1263                                  Tonne kilometres
# 1264                                Tonnes per hectare
# 1265                                               USD
# 1266                                             Total
# 1267                                             Urban
# 1268                                             Rural
#
# [1269 rows x 3 columns]

# %% [markdown]
# ## Convert XML to CSV
# Create an empty dataframe:

# %%
xml_data=pd.DataFrame()

# %% [markdown]
# Populate csv_data with values from XML:

# %%
count=0
for series in xml.iter('Series'):
    disaggregations=str(series.attrib).strip("{}").split(", ")
    for obs in series.findall('Obs'):
        attributes=str(obs.attrib).strip("{}").split(", ")
        col=[]
        value=[]
        for pair1 in disaggregations:
            col.append(pair1.split(": ")[0].strip("'"))
            value.append(pair1.split(": ")[1].strip("'"))
        for pair2 in attributes:
            col.append(pair2.split(": ")[0].strip("'"))
            value.append(pair2.split(": ")[1].strip("'"))
        row=pd.DataFrame([value], columns=col)
        if count==0:
            xml_data=pd.DataFrame(columns=col)
        count+=1
        xml_data=xml_data.append(row, sort=True).reset_index(drop=True)
xml_data.head()
# Out:
#     AGE COMMENT_OBS COMPOSITE_BREAKDOWN CUST_BREAKDOWN DISABILITY_STATUS  \
# 0    _T         NaN                  _T             _T                _T
# 1  Y0T4         NaN                  _T             _T                _T
# 2  Y0T4         NaN                  _T             _T                _T
# 3  Y0T4         NaN                  _T             _T                _T
# 4  Y0T4         NaN                  _T             _T                _T
#
#   EDUCATION_LEV FREQ INCOME_WEALTH_QUANTILE NATURE OBS_STATUS     ...       \
# 0            _T    A                     _T      C          A     ...
# 1            _T    A                     _T      C          A     ...
# 2            _T    A                     _T      C          A     ...
# 3            _T    A                     _T      C          A     ...
# 4            _T    A                     _T      C          A     ...
#
#   REF_AREA REPORTING_TYPE       SERIES SEX SOURCE_DETAIL TIME_DETAIL  \
# 0       UG              N  SI_POV_NAHC  _T          UNHS        2017
# 1       UG              N  SH_STA_STNT   F          UDHS        2016
# 2       UG              N  SH_STA_STNT   F          UDHS        2011
# 3       UG              N  SH_STA_STNT   M          UDHS        2016
# 4       UG              N  SH_STA_STNT   M          UDHS        2011
#
#   TIME_PERIOD UNIT_MEASURE UNIT_MULT URBANISATION
# 0        2017      PERCENT         0           _T
# 1        2016      PERCENT         0           _T
# 2        2011      PERCENT         0           _T
# 3        2016      PERCENT         0           _T
# 4        2011      PERCENT         0           _T
#
# [5 rows x 22 columns]

# %% [markdown]
# Drop columns that just contain "_T" as this means that there is only one breakdown type so column is not required:

# %%
for column in xml_data:
    if len(set(list(xml_data[column])))==1 and set(list(xml_data[column]))=={"_T"}:
        xml_data.drop(columns=column, inplace=True)

# rename OBS_VALUE column
xml_data.rename(columns={"OBS_VALUE":"_REPVAR_"}, inplace=True)
        
xml_data.head()
# Out:
#     AGE COMMENT_OBS DISABILITY_STATUS FREQ NATURE OBS_STATUS _REPVAR_  \
# 0    _T         NaN                _T    A      C          A     21.4
# 1  Y0T4         NaN                _T    A      C          A     26.9
# 2  Y0T4         NaN                _T    A      C          A       37
# 3  Y0T4         NaN                _T    A      C          A     30.9
# 4  Y0T4         NaN                _T    A      C          A     29.9
#
#   REF_AREA REPORTING_TYPE       SERIES SEX SOURCE_DETAIL TIME_DETAIL  \
# 0       UG              N  SI_POV_NAHC  _T          UNHS        2017
# 1       UG              N  SH_STA_STNT   F          UDHS        2016
# 2       UG              N  SH_STA_STNT   F          UDHS        2011
# 3       UG              N  SH_STA_STNT   M          UDHS        2016
# 4       UG              N  SH_STA_STNT   M          UDHS        2011
#
#   TIME_PERIOD UNIT_MEASURE UNIT_MULT
# 0        2017      PERCENT         0
# 1        2016      PERCENT         0
# 2        2011      PERCENT         0
# 3        2016      PERCENT         0
# 4        2011      PERCENT         0

# %% [markdown]
# ## Convert csv_data to values found in mapping
# Create a new empty dataframe (same length as csv_data):

# %%
csv_data=pd.DataFrame(index=xml_data.index)

# %% [markdown]
# For each row in csv_data, convert DSD code id to DSD code name using mapping:

# %%
for i in xml_data.index:
    for col in xml_data.drop(columns=["TIME_PERIOD", "_REPVAR_"]).columns:
        try:
            csv_data.at[i, col]=mapping['Name'].loc[mapping['Code']==xml_data.at[i, col]].loc[mapping['Codelist']==col].item()
        except ValueError:
            pass
    for col in xml_data[["_REPVAR_", "TIME_PERIOD"]].columns:
        csv_data.at[i, col]=xml_data.at[i,col]

# %% [markdown]
# Below you can the difference between the csv_data and indicator dataframes:

# %%
xml_data.tail()
# Out:
#       AGE COMMENT_OBS DISABILITY_STATUS FREQ NATURE OBS_STATUS _REPVAR_  \
# 96   Y0T4         NaN                _T    A      C          A     32.2
# 97   Y0T4         NaN                _T    A      C          A     32.2
# 98     _T         NaN                _T    A      C          A       35
# 99     _T         NaN                _T    A      C          A       32
# 100    _T         NaN                _T    A      C          A       39
#
#     REF_AREA REPORTING_TYPE       SERIES SEX SOURCE_DETAIL TIME_DETAIL  \
# 96        UG              N  SG_REG_BRTH   M          UDHS        2017
# 97        UG              N  SG_REG_BRTH  _T          UDHS        2017
# 98        UG              N  VC_VOV_DCMN  _T         NGPSS        2017
# 99        UG              N  VC_VOV_DCMN   F         NGPSS        2017
# 100       UG              N  VC_VOV_DCMN   M         NGPSS        2017
#
#     TIME_PERIOD UNIT_MEASURE UNIT_MULT
# 96         2017      PERCENT         0
# 97         2017      PERCENT         0
# 98         2017      PERCENT         0
# 99         2017      PERCENT         0
# 100        2017      PERCENT         0

# %%
csv_data.tail()
# Out:
#                                        AGE    FREQ        NATURE  \
# 96                       under 5 years old  Annual  Country Data
# 97                       under 5 years old  Annual  Country Data
# 98   All age ranges or no breakdown by age  Annual  Country Data
# 99   All age ranges or no breakdown by age  Annual  Country Data
# 100  All age ranges or no breakdown by age  Annual  Country Data
#
#        OBS_STATUS REPORTING_TYPE                                SEX  \
# 96   Normal value       National                               Male
# 97   Normal value       National  Both sexes or no breakdown by sex
# 98   Normal value       National  Both sexes or no breakdown by sex
# 99   Normal value       National                             Female
# 100  Normal value       National                               Male
#
#     UNIT_MEASURE UNIT_MULT _REPVAR_ TIME_PERIOD
# 96       Percent     Units     32.2        2017
# 97       Percent     Units     32.2        2017
# 98       Percent     Units       35        2017
# 99       Percent     Units       32        2017
# 100      Percent     Units       39        2017

# %% [markdown]
# ## Write out indicator to CSV
# To view all of the csv data, view the outputted CSV file:

# %%
csv_data.to_csv("uganda_xml2csv.csv", encoding="utf-8")
